# %% [markdown]
# #### In this assignment you are asked to implement uninformed and informed search algorithms for the Romanian road map data given in your textbook.
#
# <img src="images/romania-cites-map.png" width=1012 height=674/>
#
#
#
#
# #### For the informed search, when the goal city is Bucharest, the straight-line distance heuristic is given in the textbook. When the goal city is different from Bucharest, one must estimate the straight-line distance (SLD) by using the triangle inequality from elementary geometry (the side of a triangle is less than or equal to the sum of the other two sides). Consider at least two ways of doing this, and hence two different heuristics.
#
#
#
# ### BFS solution

# %%
import time
from collections import deque

# Build the graph
romanian_map = {
    'Oradea': ['Zerind', 'Sibiu'],
    'Zerind': ['Arad', 'Oradea'],
    'Arad': ['Timisoara', 'Sibiu', 'Zerind'], 
    'Timisoara': ['Arad', 'Lugoj'],
    'Lugoj': ['Mehadia', 'Timisoara'],
    'Mehadia': ['Drobeta', 'Lugoj'],
    'Drobeta': ['Mehadia', 'Craiova'],
    'Craiova': ['Drobeta', 'Rimnicu Vilcea', 'Pitesti'],
    'Rimnicu Vilcea': ['Sibiu', 'Craiova', 'Pitesti'],
    'Sibiu': ['Oradea', 'Arad', 'Fagaras', 'Rimnicu Vilcea'],
    'Fagaras': ['Sibiu', 'Bucharest'],
    'Pitesti': ['Rimnicu Vilcea', 'Craiova', 'Bucharest'],
    'Bucharest': ['Fagaras', 'Pitesti', 'Giurgiu', 'Urziceni'],
    'Giurgiu': ['Bucharest'],
    'Urziceni': ['Vaslui', 'Bucharest', 'Hirsova'],
    'Hirsova': ['Urziceni', 'Eforie'],
    'Eforie': ['Hirsova'],
    'Vaslui': ['Iasi', 'Urziceni'],
    'Iasi': ['Vaslui', 'Neamt'],
    'Neamt': ['Iasi']
}

straight_line_distance_to_bucharest = {
    'Oradea': 380,
    'Zerind': 374,
    'Arad': 366,
    'Timisoara': 329,
    'Lugoj': 244,
    'Mehadia': 241,
    'Drobeta': 242,
    'Craiova': 160,
    'Rimnicu Vilcea': 193,
    'Sibiu': 253,
    'Fagaras': 176,
    'Pitesti': 98,
    'Bucharest': 0,
    'Giurgiu': 77,
    'Urziceni': 80,
    'Hirsova': 151,
    'Eforie': 161,
    'Vaslui': 199,
    'Iasi': 226,
    'Neamt': 234
}

# %%
# BFS
def bfs(start_city, goal_city):
    """
    
    :param start_city: the starting city
    :param goal_city: the city where we want to reach
    :return: path from start city to goal city or None if no path found
    """
    # to keep track of the visited nodes
    visited = set(start_city)
    
    # to keep track of the paths to explore
    queue = deque([[start_city]])
    
    while queue:
        path = queue.popleft()
        city = path[-1]
        
        # check if the current city is the goal city
        if city == goal_city:
            return path
        
        if city not in visited:
            # mark the city as visited by adding it to the visited set
            visited.add(city)
            
            # add the next possible cities to the queue by exploring the neighbor cities of the current city
            for neighbor_city in romanian_map[city]:
                new_path = path + [neighbor_city]
                queue.append(new_path)
                
    return None

# %%
# testing function with starting and ending cities
response = bfs('Arad', 'Bucharest')
print(' -> '.join(response))
# Out:
# Arad -> Sibiu -> Fagaras -> Bucharest

# %%
def dfs(start_city, goal_city):
    """
    
    :param start_city: the starting city
    :param goal_city: the city where we want to reach
    :return: path from start city to goal city or None if no path found
    """
    
    # to keep track of the visited nodes
    visited = set(start_city)
    
    # to keep track of the paths to explore
    stack = [[start_city]]
    
    while stack:
        # pop the last path
        path = stack.pop()
        city = path[-1]
        
        # check if the current city is the goal city
        if city == goal_city:
            return path
        
        if city not in visited:
            # mark the city as visited by adding it to the visited set
            visited.add(city)
            
            # add the next possible cities to the stack by exploring the neighbor cities of the current city
            for neighbor_city in romanian_map[city]:
                new_path = path + [neighbor_city]
                stack.append(new_path)
    
    # if no path is found           
    return None

# %%
from queue import PriorityQueue


def best_first_search(start_city, goal_city):
    """
    (Greedy Best First Search)
    
    :param start_city: the starting city
    :param goal_city: the city where we want to reach
    :return: path from start city to goal city or None if no path found
    """
    
    # to keep track of the visited nodes
    visited = set(start_city)
    
    # to keep track of the paths to explore
    queue = PriorityQueue()
    queue.put((0, [start_city]))
    
    while not queue.empty():
        _, path = queue.get()
        city = path[-1]
        
        # check if the current city is the goal city
        if city == goal_city:
            return path
        
        if city not in visited:
            # mark the city as visited by adding it to the visited set
            visited.add(city)
            
            # add the next possible cities to the queue by exploring the neighbor cities of the current city
            for neighbor_city in romanian_map[city]:
                new_path = path + [neighbor_city]
                # the straight line distance from the current city to the neighbor city
                queue.put((straight_line_distance_to_bucharest[neighbor_city], new_path))

    # if no path is found           
    return None

# %%
from queue import PriorityQueue


def a_star(start_city: str, goal_city: str, heuristics, graph):
    
    queue = PriorityQueue()
    
    distance = 0
    path = []

# %%
# Time the algorithm with different starting and ending cities
import random, time
cities = list(romanian_map.keys())

average_time = 0
for i in range(100):
    
    current_city = random.choice(cities)
    end_city = random.choice(cities)
    start_time = time.time_ns()
    response = bfs(current_city, end_city)
    total_time = time.time_ns() - start_time
    average_time += total_time
    if response:
        print(f"starting city: {current_city}, ending city: {end_city}\npath: {' -> '.join(response)}\nTotal time: {total_time} nanoseconds\n{'*' * 100}")
    else:
        print(f"starting city: {current_city}, ending city: {end_city}\nno path found\nTotal time: {total_time} nanoseconds\n{'*' * 100}")
print(f"Average time: {average_time / 100} nanoseconds")
# Out:
# starting city: Vaslui, ending city: Iasi
# path: Vaslui -> Iasi
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Zerind, ending city: Rimnicu Vilcea
# path: Zerind -> Arad -> Sibiu -> Rimnicu Vilcea
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Giurgiu, ending city: Vaslui
# path: Giurgiu -> Bucharest -> Urziceni -> Vaslui
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Sibiu
# path: Bucharest -> Fagaras -> Sibiu
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Pitesti
# path: Bucharest -> Pitesti
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Craiova, ending city: Rimnicu Vilcea
# path: Craiova -> Rimnicu Vilcea
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Eforie
# path: Iasi -> Vaslui -> Urziceni -> Hirsova -> Eforie
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Craiova, ending city: Neamt
# path: Craiova -> Pitesti -> Bucharest -> Urziceni -> Vaslui -> Iasi -> Neamt
# Total time: 13000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Pitesti
# path: Oradea -> Sibiu -> Rimnicu Vilcea -> Pitesti
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Rimnicu Vilcea
# path: Timisoara -> Arad -> Sibiu -> Rimnicu Vilcea
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Hirsova
# path: Bucharest -> Urziceni -> Hirsova
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Neamt, ending city: Sibiu
# path: Neamt -> Iasi -> Vaslui -> Urziceni -> Bucharest -> Fagaras -> Sibiu
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Pitesti, ending city: Eforie
# path: Pitesti -> Bucharest -> Urziceni -> Hirsova -> Eforie
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Rimnicu Vilcea
# path: Fagaras -> Sibiu -> Rimnicu Vilcea
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Hirsova
# path: Iasi -> Vaslui -> Urziceni -> Hirsova
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Eforie, ending city: Lugoj
# path: Eforie -> Hirsova -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Arad -> Timisoara -> Lugoj
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Fagaras
# path: Fagaras
# Total time: 0 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Arad
# path: Iasi -> Vaslui -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Arad
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Zerind, ending city: Eforie
# path: Zerind -> Arad -> Sibiu -> Fagaras -> Bucharest -> Urziceni -> Hirsova -> Eforie
# Total time: 12000 nanoseconds
# ****************************************************************************************************
# starting city: Vaslui, ending city: Fagaras
# path: Vaslui -> Urziceni -> Bucharest -> Fagaras
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Oradea
# path: Rimnicu Vilcea -> Sibiu -> Oradea
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Giurgiu
# path: Bucharest -> Giurgiu
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Arad, ending city: Pitesti
# path: Arad -> Sibiu -> Rimnicu Vilcea -> Pitesti
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Rimnicu Vilcea
# path: Oradea -> Sibiu -> Rimnicu Vilcea
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Urziceni
# path: Bucharest -> Urziceni
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Vaslui, ending city: Lugoj
# path: Vaslui -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Arad -> Timisoara -> Lugoj
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Lugoj, ending city: Craiova
# path: Lugoj -> Mehadia -> Drobeta -> Craiova
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Sibiu, ending city: Fagaras
# path: Sibiu -> Fagaras
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Fagaras
# path: Oradea -> Sibiu -> Fagaras
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Drobeta
# path: Hirsova -> Urziceni -> Bucharest -> Pitesti -> Craiova -> Drobeta
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Zerind, ending city: Rimnicu Vilcea
# path: Zerind -> Arad -> Sibiu -> Rimnicu Vilcea
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Sibiu, ending city: Giurgiu
# path: Sibiu -> Fagaras -> Bucharest -> Giurgiu
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Giurgiu
# path: Rimnicu Vilcea -> Pitesti -> Bucharest -> Giurgiu
# Total time: 8000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Urziceni
# path: Hirsova -> Urziceni
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Lugoj, ending city: Arad
# path: Lugoj -> Timisoara -> Arad
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Eforie
# path: Oradea -> Sibiu -> Fagaras -> Bucharest -> Urziceni -> Hirsova -> Eforie
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Drobeta
# path: Rimnicu Vilcea -> Craiova -> Drobeta
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Fagaras
# path: Oradea -> Sibiu -> Fagaras
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Urziceni, ending city: Urziceni
# path: Urziceni
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Bucharest
# path: Bucharest
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Timisoara
# path: Drobeta -> Mehadia -> Lugoj -> Timisoara
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Giurgiu, ending city: Timisoara
# path: Giurgiu -> Bucharest -> Fagaras -> Sibiu -> Arad -> Timisoara
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Mehadia
# path: Oradea -> Zerind -> Arad -> Timisoara -> Lugoj -> Mehadia
# Total time: 8000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Bucharest
# path: Timisoara -> Arad -> Sibiu -> Fagaras -> Bucharest
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Pitesti
# path: Rimnicu Vilcea -> Pitesti
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Lugoj, ending city: Fagaras
# path: Lugoj -> Timisoara -> Arad -> Sibiu -> Fagaras
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Zerind, ending city: Fagaras
# path: Zerind -> Arad -> Sibiu -> Fagaras
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Timisoara
# path: Rimnicu Vilcea -> Sibiu -> Arad -> Timisoara
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Pitesti, ending city: Fagaras
# path: Pitesti -> Bucharest -> Fagaras
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Mehadia
# path: Drobeta -> Mehadia
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Giurgiu, ending city: Bucharest
# path: Giurgiu -> Bucharest
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Vaslui
# path: Fagaras -> Bucharest -> Urziceni -> Vaslui
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Neamt
# path: Rimnicu Vilcea -> Pitesti -> Bucharest -> Urziceni -> Vaslui -> Iasi -> Neamt
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Urziceni
# path: Iasi -> Vaslui -> Urziceni
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Hirsova
# path: Oradea -> Sibiu -> Fagaras -> Bucharest -> Urziceni -> Hirsova
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Sibiu, ending city: Craiova
# path: Sibiu -> Rimnicu Vilcea -> Craiova
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Fagaras
# path: Rimnicu Vilcea -> Sibiu -> Fagaras
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Hirsova
# path: Drobeta -> Craiova -> Pitesti -> Bucharest -> Urziceni -> Hirsova
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Bucharest, ending city: Drobeta
# path: Bucharest -> Pitesti -> Craiova -> Drobeta
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Rimnicu Vilcea
# path: Drobeta -> Craiova -> Rimnicu Vilcea
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Mehadia, ending city: Neamt
# path: Mehadia -> Drobeta -> Craiova -> Pitesti -> Bucharest -> Urziceni -> Vaslui -> Iasi -> Neamt
# Total time: 12000 nanoseconds
# ****************************************************************************************************
# starting city: Sibiu, ending city: Vaslui
# path: Sibiu -> Fagaras -> Bucharest -> Urziceni -> Vaslui
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Rimnicu Vilcea
# path: Fagaras -> Sibiu -> Rimnicu Vilcea
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Arad
# path: Timisoara -> Arad
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Giurgiu, ending city: Zerind
# path: Giurgiu -> Bucharest -> Fagaras -> Sibiu -> Oradea -> Zerind
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Giurgiu, ending city: Oradea
# path: Giurgiu -> Bucharest -> Fagaras -> Sibiu -> Oradea
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Lugoj, ending city: Hirsova
# path: Lugoj -> Mehadia -> Drobeta -> Craiova -> Pitesti -> Bucharest -> Urziceni -> Hirsova
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Iasi
# path: Fagaras -> Bucharest -> Urziceni -> Vaslui -> Iasi
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Oradea
# path: Iasi -> Vaslui -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Oradea
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Eforie, ending city: Timisoara
# path: Eforie -> Hirsova -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Arad -> Timisoara
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Urziceni, ending city: Neamt
# path: Urziceni -> Vaslui -> Iasi -> Neamt
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Mehadia
# path: Hirsova -> Urziceni -> Bucharest -> Pitesti -> Craiova -> Drobeta -> Mehadia
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Oradea, ending city: Drobeta
# path: Oradea -> Sibiu -> Rimnicu Vilcea -> Craiova -> Drobeta
# Total time: 8000 nanoseconds
# ****************************************************************************************************
# starting city: Rimnicu Vilcea, ending city: Mehadia
# path: Rimnicu Vilcea -> Craiova -> Drobeta -> Mehadia
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Arad, ending city: Hirsova
# path: Arad -> Sibiu -> Fagaras -> Bucharest -> Urziceni -> Hirsova
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Drobeta
# path: Timisoara -> Lugoj -> Mehadia -> Drobeta
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Timisoara
# path: Timisoara
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Giurgiu
# path: Hirsova -> Urziceni -> Bucharest -> Giurgiu
# Total time: 5000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Timisoara
# path: Drobeta -> Mehadia -> Lugoj -> Timisoara
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Craiova, ending city: Hirsova
# path: Craiova -> Pitesti -> Bucharest -> Urziceni -> Hirsova
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Mehadia, ending city: Pitesti
# path: Mehadia -> Drobeta -> Craiova -> Pitesti
# Total time: 4000 nanoseconds
# ****************************************************************************************************
# starting city: Pitesti, ending city: Bucharest
# path: Pitesti -> Bucharest
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Giurgiu
# path: Timisoara -> Arad -> Sibiu -> Fagaras -> Bucharest -> Giurgiu
# Total time: 8000 nanoseconds
# ****************************************************************************************************
# starting city: Vaslui, ending city: Mehadia
# path: Vaslui -> Urziceni -> Bucharest -> Pitesti -> Craiova -> Drobeta -> Mehadia
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Timisoara, ending city: Craiova
# path: Timisoara -> Arad -> Sibiu -> Rimnicu Vilcea -> Craiova
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Urziceni, ending city: Drobeta
# path: Urziceni -> Bucharest -> Pitesti -> Craiova -> Drobeta
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Mehadia, ending city: Rimnicu Vilcea
# path: Mehadia -> Drobeta -> Craiova -> Rimnicu Vilcea
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Fagaras, ending city: Sibiu
# path: Fagaras -> Sibiu
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Vaslui
# path: Hirsova -> Urziceni -> Vaslui
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Craiova, ending city: Giurgiu
# path: Craiova -> Pitesti -> Bucharest -> Giurgiu
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# starting city: Sibiu, ending city: Oradea
# path: Sibiu -> Oradea
# Total time: 1000 nanoseconds
# ****************************************************************************************************
# starting city: Arad, ending city: Eforie
# path: Arad -> Sibiu -> Fagaras -> Bucharest -> Urziceni -> Hirsova -> Eforie
# Total time: 11000 nanoseconds
# ****************************************************************************************************
# starting city: Arad, ending city: Sibiu
# path: Arad -> Sibiu
# Total time: 2000 nanoseconds
# ****************************************************************************************************
# starting city: Eforie, ending city: Drobeta
# path: Eforie -> Hirsova -> Urziceni -> Bucharest -> Pitesti -> Craiova -> Drobeta
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Vaslui, ending city: Rimnicu Vilcea
# path: Vaslui -> Urziceni -> Bucharest -> Pitesti -> Rimnicu Vilcea
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Iasi, ending city: Zerind
# path: Iasi -> Vaslui -> Urziceni -> Bucharest -> Fagaras -> Sibiu -> Oradea -> Zerind
# Total time: 10000 nanoseconds
# ****************************************************************************************************
# starting city: Hirsova, ending city: Craiova
# path: Hirsova -> Urziceni -> Bucharest -> Pitesti -> Craiova
# Total time: 6000 nanoseconds
# ****************************************************************************************************
# starting city: Lugoj, ending city: Giurgiu
# path: Lugoj -> Mehadia -> Drobeta -> Craiova -> Pitesti -> Bucharest -> Giurgiu
# Total time: 9000 nanoseconds
# ****************************************************************************************************
# starting city: Drobeta, ending city: Pitesti
# path: Drobeta -> Craiova -> Pitesti
# Total time: 3000 nanoseconds
# ****************************************************************************************************
# starting city: Urziceni, ending city: Craiova
# path: Urziceni -> Bucharest -> Pitesti -> Craiova
# Total time: 7000 nanoseconds
# ****************************************************************************************************
# Average time: 5850.0 nanoseconds

# %%
response = best_first_search('Arad', 'Bucharest')
print(' -> '.join(response))
# Out:
# Arad -> Sibiu -> Fagaras -> Bucharest
